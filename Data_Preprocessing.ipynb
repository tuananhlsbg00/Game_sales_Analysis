# %%
import numpy as np
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt

# %%
import dataframe_image as dfi

# %%
data = pd.read_csv('MAS291 Project.csv')

# %%
# data.head()
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                            FIFA 17      PS4             2016        Sports
# 1          Uncharted 4: A Thiefs End      PS4             2016       Shooter
# 2     Call of Duty: Infinite Warfare      PS4             2016       Shooter
# 3                      Battlefield 1      PS4             2016       Shooter
# 4           Tom Clancys The Division      PS4             2016       Shooter
# ...                              ...      ...              ...           ...
# 1431                  Gran Turismo 2       PS             1999        Racing
# 1432              Final Fantasy VIII       PS             1999  Role-Playing
# 1433                          Driver       PS             1999        Action
# 1434               Crash Team Racing       PS             1999        Racing
# 1435                Metal Gear Solid       PS             1998        Action
#
# ...

# %%
data.shape
# Out:
# (1436, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1436 non-null   object
#  1   Platform         1436 non-null   object
#  2   Year_of_Release  1436 non-null   int64
#  3   Genre            1436 non-null   object
#  4   NA_Sales         1436 non-null   float64
#  5   EU_Sales         1436 non-null   float64
#  6   JP_Sales         1436 non-null   float64
#  7   Other_Sales      1436 non-null   float64
#  8   Global_Sales     1436 non-null   float64
#  9   Critic_Score     1436 non-null   int64
#  10  Critic_Count     1436 non-null   int64
#  11  User_Score       1433 non-null   float64
#  12  User_Count       1433 non-null   float64
#  13  Rating           1433 non-null   object
# dtypes: float64(7), int64(3), object(4)
# memory usage: 157.2+ KB

# %%
data.describe().to_excel('test.xlsx')

# %%
im = data.describe()
im
# dfi.export(im, 'im.png')
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      1436.000000  1436.000000  1436.000000  1436.000000  1436.000000
# mean       2008.890669     0.949596     0.642403     0.242625     0.223419
# std           3.901205     1.868641     1.337321     0.557823     0.526854
# min        1998.000000     0.010000     0.010000     0.010000     0.010000
# 25%        2006.000000     0.180000     0.080000     0.020000     0.030000
# 50%        2009.000000     0.430000     0.260000     0.070000     0.090000
# 75%        2012.000000     1.010000     0.672500     0.210000     0.230000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Score    User_Count
# count   1436.000000   1436.000000   1436.000000  1433.000000   1433.000000
# mean       2.057744     76.661560     48.454735     7.568039    376.313329
# ...

# %%
data['NA_Sales'].describe()
# Out:
# count    1436.000000
# mean        0.949596
# std         1.868641
# min         0.010000
# 25%         0.180000
# 50%         0.430000
# 75%         1.010000
# max        41.360000
# Name: NA_Sales, dtype: float64

# %%
data['NA_Sales'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.boxplot([data['NA_Sales'], data['EU_Sales'], data['JP_Sales']])
plt.xticks([1, 2, 3], ['NA', 'EU', 'JP'])
plt.ylabel('Sale (in milions)')
plt.xlabel('Region')
# plt.savefig('test.png')
plt.show()

# %%
data2 = data.loc[data['Global_Sales'] < data['Global_Sales'].sort_values(ascending=False).reset_index(drop=True)[1000]]

plt.boxplot([data2['NA_Sales'], data2['EU_Sales'], data2['JP_Sales']])
plt.xticks([1, 2, 3], ['NA', 'EU', 'JP'])
plt.ylabel('Sale (in milions)')
plt.xlabel('Region')
# plt.savefig('test.png')
plt.show()

# %%
data['NA_Sales'].sort_values(ascending=False).reset_index(drop=True)[10]
# Out:
# 9.43

# %%
data.sort_values(by='Global_Sales', ascending=False).head(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data.sort_values(by='Global_Sales', ascending=False).head(1)
#
# AttributeError: 'list' object has no attribute 'sort_values'

# %%
data2.loc[data2['NA_Sales'] == data2['NA_Sales'].max()]
# Out:
#               Name Platform  Year_of_Release   Genre  NA_Sales  EU_Sales  \
# 1269  Spider-Man 2       DS             2004  Action      0.41      0.02
#
#       JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 1269      0.03         0.04           0.5            61            46
#
#       User_Score  User_Count Rating
# 1269         5.0         6.0      E

# %%
gen = np.flip(data['Genre'].value_counts())
plt.pie(gen, labels = gen.index, startangle=90, autopct='%1.1f%%')
plt.show()

# %%
# def func
print(gen)
gen = np.flip(data['Rating'].value_counts())
plt.pie(gen, labels = gen.index, startangle=90, autopct=lambda pct: f"{(pct/100*sum(gen)):.0f}\ndau game")
plt.title('Rating')
plt.show()
# Out:
# Genre
# Strategy         24
# Puzzle           29
# Adventure        33
# Simulation       47
# Misc             64
# Platform         87
# Racing           94
# Sports          103
# Fighting        107
# Shooter         227
# Role-Playing    253
# Action          368
# Name: count, dtype: int64

# %%
data[['NA_Sales', 'JP_Sales', 'EU_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score', 'User_Score']]
# Out:
#       NA_Sales  JP_Sales  EU_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0         0.90      0.09      6.75         1.33          9.07            85
# 1         2.92      0.19      2.98         1.18          7.28            93
# 2         2.15      0.16      2.57         0.93          5.80            77
# 3         1.45      0.23      2.81         0.81          5.30            89
# 4         1.37      0.15      1.85         0.63          4.00            80
# ...        ...       ...       ...          ...           ...           ...
# 1431      3.88      1.69      3.42         0.50          9.49            93
# 1432      2.28      3.63      1.72         0.23          7.86            90
# 1433      3.11      0.02      2.80         0.33          6.27            87
# 1434      2.57      0.44      1.57         0.21          4.79            88
# 1435      3.18      0.78      1.83         0.24          6.03            94
#
#       User_Score
# 0            4.9
# 1            7.9
# ...

# %%
cor = data[['NA_Sales', 'JP_Sales', 'EU_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score', 'User_Score']].corr()
cor
# Out:
#               NA_Sales  JP_Sales  EU_Sales  Other_Sales  Global_Sales  \
# NA_Sales      1.000000  0.447023  0.862833     0.734320      0.959310
# JP_Sales      0.447023  1.000000  0.507153     0.351720      0.591697
# EU_Sales      0.862833  0.507153  1.000000     0.726417      0.947895
# Other_Sales   0.734320  0.351720  0.726417     1.000000      0.804086
# Global_Sales  0.959310  0.591697  0.947895     0.804086      1.000000
# Critic_Score  0.270853  0.126073  0.237250     0.240001      0.267425
# User_Score    0.060130  0.168564 -0.014778     0.021233      0.051885
#
#               Critic_Score  User_Score
# NA_Sales          0.270853    0.060130
# JP_Sales          0.126073    0.168564
# EU_Sales          0.237250   -0.014778
# Other_Sales       0.240001    0.021233
# Global_Sales      0.267425    0.051885
# Critic_Score      1.000000    0.519919
# User_Score        0.519919    1.000000

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(cor, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(cor.columns)), cor.columns, rotation='vertical');
plt.yticks(range(len(cor.columns)), cor.columns);

# %%
print(rate_sale['Global_Sales'].values)
print(rate_sale.values)
print(rate_sale['Global_Sales'].index)
print(rate_sale.columns)
data[['Rating', 'Global_Sales']].groupby(['Rating']).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(rate_sale['Global_Sales'].values)
#       2 print(rate_sale.values)
#       3 print(rate_sale['Global_Sales'].index)
#
# NameError: name 'rate_sale' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} g)"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()

# %%
data2 = data['Global_Sales'].value_counts()
# print(data2)
# data3 = data

# plt.bar(data2.index, data2)
# plt.show
plt.hist(data2, bins = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data2 = data['Global_Sales'].value_counts()
#       2 # print(data2)
#       3 # data3 = data
#       4
#       5 # plt.bar(data2.index, data2)
#       6 # plt.show
#       7 plt.hist(data2, bins = 20)
#
# TypeError: list indices must be integers or slices, not str

# %%
no_outline = data.loc[data['Global_Sales'] > data['Global_Sales'].sort_values(ascending=True).reset_index(drop=True)[0]]

mean = no_outline['Global_Sales'].mean()
std = no_outline['Global_Sales'].std()
normalized = (no_outline['Global_Sales'] - mean)/std
data3 = normalized.value_counts()

fig, x = plt.subplots(1, 2)
x[0].bar(data3.index, data3)
x[1].hist(normalized, bins = 50)
plt.show()

# %%
no_outline = data.loc[data['Global_Sales'] < data['Global_Sales'].sort_values(ascending=False).reset_index(drop=True)[100]]
print(no_outline['Global_Sales'])
# Out:
# 3       5.30
# 4       4.00
# 5       3.44
# 6       3.37
# 7       2.57
#         ...
# 1427    1.24
# 1428    0.99
# 1429    0.95
# 1430    0.79
# 1434    4.79
# Name: Global_Sales, Length: 1335, dtype: float64

# %%
no_outline = data.loc[data['Global_Sales'] < data['Global_Sales'].sort_values(ascending=False).reset_index(drop=True)[10]]
# no_outline = no_outline.loc[no_outline['Rating'].isin(['M', 'T','E10+'])]
# no_outline = no_outline.loc[no_outline['JP_Sales'] < 0.6 * no_outline['Global_Sales']]
# m, b = np.polyfit(no_outline['NA_Sales'], no_outline['Global_Sales'] - no_outline['NA_Sales'], 1)
fg, ax = plt.subplots(figsize=(10,11))
ax.scatter(no_outline['JP_Sales'], no_outline['Global_Sales'] - no_outline['JP_Sales'])
# ax.plot(no_outline['NA_Sales'], m*(no_outline['NA_Sales']) + b, color = 'violet', linewidth = 5)
# ax.scatter(no_outline['NA_Sales'], no_outline['JP_Sales'])# - no_outline['NA_Sales'])
plt.ylabel(ylabel='Global_Sales')
plt.xlabel(xlabel='JP_Sales')
plt.show()

# %%
minusNA = no_outline[['NA_Sales','Global_Sales']].copy()

minusNA['Worldwide Exclude NA']= minusNA['Global_Sales'] - minusNA['NA_Sales']
minusNA.to_csv('ExculdeNA.csv', index=False, header=True, sep=',', encoding='utf-8')
minusNA
# minusNA
# Out:
#       NA_Sales  Global_Sales  Worldwide Exclude NA
# 1         2.92          7.28                  4.36
# 2         2.15          5.80                  3.65
# 3         1.45          5.30                  3.85
# 4         1.37          4.00                  2.63
# 5         2.14          3.44                  1.30
# ...        ...           ...                   ...
# 1430      0.28          0.79                  0.51
# 1431      3.88          9.49                  5.61
# 1432      2.28          7.86                  5.58
# 1433      3.11          6.27                  3.16
# 1435      3.18          6.03                  2.85
#
# [1045 rows x 3 columns]

# %%
import os
print(os.getcwd())
# Out:
# D:\Document\Code\Python\MAS Project

# %%
no_outline = data.loc[data['Global_Sales'] < data['Global_Sales'].sort_values(ascending=False).reset_index(drop=True)[10]]
no_outline = no_outline.loc[no_outline['Critic_Count'] > 30]
# no_outline = no_outline.loc[no_outline['Critic_Score'] > 50]
no_outline = no_outline.loc[no_outline['Rating'].isin(['M', 'T'])]
no_outline = no_outline.loc[no_outline['JP_Sales'] < 0.5 * no_outline['Global_Sales']]
fg, ax = plt.subplots(figsize=(5,8))
ax.scatter(no_outline['Critic_Score'], no_outline['Global_Sales'])
Critic_Score_n_Global_Sales = no_outline[['Critic_Score','Global_Sales']].copy()
Critic_Score_n_Global_Sales.to_csv('Critic_Score_n_Global_Sales.csv', index=False, header=True, sep=',', encoding='utf-8')
NA_Critic_Global = no_outline.copy()
NA_Critic_Global['Exclude NA'] = NA_Critic_Global['Global_Sales'] - NA_Critic_Global['NA_Sales']
NA_Critic_Global.to_csv('Train_Data.csv', index=False, header=True, sep=',', encoding='utf-8')
# plt.show()

no_outline
# Out:
#                                            Name Platform  Year_of_Release  \
# 1                     Uncharted 4: A Thiefs End      PS4             2016
# 2                Call of Duty: Infinite Warfare      PS4             2016
# 3                                 Battlefield 1      PS4             2016
# 4                      Tom Clancys The Division      PS4             2016
# 5                                 Battlefield 1     XOne             2016
# ...                                         ...      ...              ...
# 1388        Metal Gear Solid 2: Sons of Liberty      PS2             2001
# 1391                    Tony Hawks Pro Skater 3      PS2             2001
# 1399                              Devil May Cry      PS2             2001
# 1406  Star Wars Rogue Leader: Rogue Squadron II       GC             2001
# 1407                            Dead or Alive 3        X             2001
#
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# ...

# %%
Cor = NA_Critic_Global[['NA_Sales','Exclude NA']].corr()
Cor
# Out:
#             NA_Sales  Exclude NA
# NA_Sales    1.000000    0.810429
# Exclude NA  0.810429    1.000000

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# Define the form of the function we want to fit
def func(x, a, b, c):
    return (a+c[0]) * np.exp((b+c[1]) * x)

# Generate some example data
x = np.linspace(0, 4, 50)
y = func(x, 2.5, 1.3) + .2 * np.random.normal(size=len(x))

# Use curve_fit to fit the function to the data
params, params_covariance = curve_fit(func, x, y)

print("Fitted function: a * exp(b * x)")
print(f"a = {params[0]}, b = {params[1]}")

# Plot the original data
plt.scatter(x, y, label='Data')

# Plot the fitted function
plt.plot(x, func(x, params[0], params[1], params_covariance), label='Fitted function')

plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 11
#       9 # Generate some example data
#      10 x = np.linspace(0, 4, 50)
# ---> 11 y = func(x, 2.5, 1.3) + .2 * np.random.normal(size=len(x))
#      13 # Use curve_fit to fit the function to the data
#      14 params, params_covariance = curve_fit(func, x, y)
#
# TypeError: func() missing 1 required positional argument: 'c'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1436 non-null   object
#  1   Platform         1436 non-null   object
#  2   Year_of_Release  1436 non-null   int64
#  3   Genre            1436 non-null   object
#  4   NA_Sales         1436 non-null   float64
#  5   EU_Sales         1436 non-null   float64
#  6   JP_Sales         1436 non-null   float64
#  7   Other_Sales      1436 non-null   float64
#  8   Global_Sales     1436 non-null   float64
#  9   Critic_Score     1436 non-null   int64
#  10  Critic_Count     1436 non-null   int64
#  11  User_Score       1433 non-null   float64
#  12  User_Count       1433 non-null   float64
#  13  Rating           1433 non-null   object
# dtypes: float64(7), int64(3), object(4)
# memory usage: 157.2+ KB

# %%
no_outline
# Out:
#                                            Name Platform  Year_of_Release  \
# 1                     Uncharted 4: A Thiefs End      PS4             2016
# 2                Call of Duty: Infinite Warfare      PS4             2016
# 3                                 Battlefield 1      PS4             2016
# 4                      Tom Clancys The Division      PS4             2016
# 5                                 Battlefield 1     XOne             2016
# ...                                         ...      ...              ...
# 1388        Metal Gear Solid 2: Sons of Liberty      PS2             2001
# 1391                    Tony Hawks Pro Skater 3      PS2             2001
# 1399                              Devil May Cry      PS2             2001
# 1406  Star Wars Rogue Leader: Rogue Squadron II       GC             2001
# 1407                            Dead or Alive 3        X             2001
#
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# ...
